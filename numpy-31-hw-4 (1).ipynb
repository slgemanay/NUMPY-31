# %% [markdown]
# Задача 1

# %%
import pandas as pd
log = pd.read_csv('visit_log.csv', sep=';')
log.head()

# %%
log.loc[log.traffic_source.isin(['yandex', 'google']), 'source_type'] = 'organic'
log.loc[((log.traffic_source == 'paid')|(log.traffic_source == 'email'))&(log.region == 'Russia'), 'source_type'] = 'ad'
log.loc[((log.traffic_source == 'paid')|(log.traffic_source == 'email'))&((log.region == 'Ukraine')|(log.region == 'India')|(log.region == 'Australia')|(log.region == 'China')|(log.region == 'Belarus')), 'source_type'] = 'other'
log
#подскажите пожалуйста, как обозначить условие все кроме Russia

# %%
log.region.value_counts()

# %% [markdown]
# Задача 2

# %%
urls = pd.read_csv('URLs.txt')
urls

# %%
template = r'/\d{8}\-'
urls['filtered_sites'] = urls.loc[urls.url.str.contains(template), 'url']
urls

# %% [markdown]
# Задача 3

# %%
df = pd.read_csv('ml-latest-small/ratings.csv')
df

# %%
def calc(user_data):
    max_timestamp = max([int(x[3]) for x in user_data])
    min_timestamp = min([int(x[3]) for x in user_data])
    lifetime = max_timestamp - min_timestamp
    return lifetime

# %%
user_average_lifetime = []
user_data = []
marks_counter = 0
previous_user = None
with open('ml-latest-small/ratings.csv') as f:
    f.readline()
    for line in f:
        userId, movieId, rating, timestamp = line.strip().split(',')
        if previous_user != None:
            if userId == previous_user:
                marks_counter +=1
                user_data.append([userId, movieId, rating, timestamp])
            else:
                previous_user = userId
                if marks_counter >= 100:
                    user_average_lifetime.append([previous_user, calc(user_data)])
                    marks_counter = 0
                else:
                    marks_counter = 0
        else:
            previous_user = userId
            user_data.append([userId, movieId, rating, timestamp])
            marks_counter = 1
user_average_lifetime

# %%
def average_lifetime(user_average_lifetime):
    value_count = 0
    counter = 0
    counter = len(user_average_lifetime)
    value_count = sum([int(x[1]) for x in user_average_lifetime])
    answer = value_count/counter
    return answer

# %%
average_lifetime(user_average_lifetime)

# %% [markdown]
# Задание 4

# %%
client_base = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115, 116, 117, 118],
        'address': ['Комсомольская 4', 'Энтузиастов 8а', 'Левобережная 1а', 'Мира 14', 'ЗЖБИиДК 1', 
                    'Строителей 18', 'Панфиловская 33', 'Мастеркова 4']
    }
)
client_base

# %%
air = pd.DataFrame(
    {
        'client_id': [115, 116, 117, 118],
        'air_revenue': [81, 4, 13, 173]
    }
)
air

# %%
auto = pd.DataFrame(
    {
        'client_id': [113, 114, 115, 116, 117],
        'auto_revenue': [57483, 83, 912, 4834, 98]
    }
)
auto

# %%
rzd = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115],
        'rzd_revenue': [1093, 2810, 10283, 5774, 981]
    }
)
rzd

# %%
promezutochnui_itog = pd.merge(rzd, auto, on='client_id', how='outer')

# %%
first_table = pd.merge(promezutochnui_itog, air, on='client_id', how='outer')
first_table

# %%
second_table = pd.merge(first_table, client_base, on='client_id', how='outer')
second_table
